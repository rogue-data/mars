# %%
# dependencies 

# !pip install bs4
# !pip install pytube
# !apt-get install ffmpeg
# !pip install pydub 
# !pip install youtube-search
# Out:
# ...
#      |████████████████████████████████| 40kB 2.4MB/s
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.
# ...

# %%
# libraries 

import bs4, requests
import os
import sys
from pytube import YouTube,Playlist
import pydub
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
from librosa.display import waveplot,specshow
from youtube_search import YoutubeSearch
from pytube import YouTube
import time

# %%
# drive mount

from google.colab import drive
drive.mount('/content/drive',force_remount=True)

# %% [markdown]
# ### the data has been reduced from 1m -> ~ 500k -> ~ 30k
#
# More features to this 30k data have been added , which would lead better results

# %%
df1=pd.read_csv("/content/song_data.csv")
df_filtered = df1[df1['year'] >= 1]
df_filtered.to_csv("/content/sdf.csv")

# %%
df_filtered
# Out:
#                    song_id  ...  year
# 0       SOQMMHC12AB0180CB8  ...  2003
# 1       SOVFVAK12A8C1350D9  ...  1995
# 2       SOGTUKN12AB017F4F1  ...  2006
# 3       SOBNYVR12A8C13558C  ...  2003
# 7       SOEYRFT12AB018936C  ...  1993
# ...                    ...  ...   ...
# 999987  SOMDVLO12A58A7A02B  ...  2004
# 999990  SOFAXZU12AB01881C4  ...  2010
# 999991  SOYFFWW12A6701C135  ...  2002
# 999992  SOBODSE12A8C13EBD6  ...  1996
# 999999  SOWXJXQ12AB0189F43  ...  2004
#
# [515576 rows x 5 columns]

# %%
df2=pd.read_csv("/content/genre_dataset.csv")
df2
res2=pd.merge(df2,df_filtered,how='inner',on=['title','artist_name'])
# res2.sort_values(by=['track_id']).set_index(np.arange(0,51638,1))
res3=res2.groupby((res2["title"] != res2["title"].shift()).cumsum().values).first()
res3
# res=pd.concat([df_filtered,df2],axis=1,join='inner')
# res
# Out:
#                       genre            track_id  ...                release  year
# 1      classic pop and rock  TRFCOOU128F427AEC0  ...               3 CD Set  2001
# 2      classic pop and rock  TRNJTPB128F427AE9F  ...       Blue Öyster Cult  1972
# 3      classic pop and rock  TRCQZAG128F427DB97  ...      AGENTS OF FORTUNE  1976
# 4      classic pop and rock  TRNXMNM128F427DB8C  ...       World's Best Dad  1976
# 5      classic pop and rock  TRSIZRN128F427DB95  ...      AGENTS OF FORTUNE  1976
# ...                     ...                 ...  ...                    ...   ...
# 34802       soul and reggae  TRGYRMA128E078FC55  ...  Worldwide Underground  2003
# 34803       soul and reggae  TRZZFQW128E078FC5A  ...  Worldwide Underground  2000
# 34804       soul and reggae  TRAMYBB128F424D86D  ...  Worldwide Underground  2003
# 34805       soul and reggae  TRABWFM128F424D86A  ...  Worldwide Underground  2003
# ...
